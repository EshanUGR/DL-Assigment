# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
file_path = "E:/7th semester/Deep Learning/labs/DL-Assigment/data/stock_data.csv"
data = pd.read_csv(file_path)
data
# Out:
#            Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0      6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1      6/1/2025   ABBV      189.63       193.64      194.31     188.03
# 2      6/1/2025    ABT      118.79       120.08      120.53     118.01
# 3      6/1/2025   ADBE      584.51       567.78      587.97     561.25
# 4      6/1/2025    ADP      253.46       255.60      258.59     249.91
# ...         ...    ...         ...          ...         ...        ...
# 4341  7/23/2025   VRTX      478.20       489.78      491.84     476.65
# 4342  7/23/2025     VZ       46.61        47.75       48.26      46.15
# 4343  7/23/2025    WMT       71.65        70.99       72.35      70.46
# 4344  7/23/2025    XOM      117.02       112.37      118.45     111.41
# 4345  7/23/2025    ZTS      146.81       148.32      150.25     145.16
#
#       Volume Traded    Market Cap  PE Ratio  Dividend Yield    EPS  52 Week   \
# ...

# %%
data.groupby('Ticker')['Ticker'].agg('count')
# Out:
# Ticker
# AAPL    53
# ABBV    53
# ABT     53
# ADBE    53
# ADP     53
#         ..
# VRTX    53
# VZ      53
# WMT     53
# XOM     53
# ZTS     53
# Name: Ticker, Length: 82, dtype: int64

# %%
## remove the irrelavant data columns in dataset

# %%
data_new = data.drop(['52_Week_Low', 'Sector'], axis='columns')
data_new.head()
# Out:
#        Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0  6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1  6/1/2025   ABBV      189.63       193.64      194.31     188.03
# 2  6/1/2025    ABT      118.79       120.08      120.53     118.01
# 3  6/1/2025   ADBE      584.51       567.78      587.97     561.25
# 4  6/1/2025    ADP      253.46       255.60      258.59     249.91
#
#    Volume Traded    Market Cap  PE Ratio  Dividend Yield    EPS  52 Week
# 0       42257183  2.931360e+12     28.37            0.49   6.62    248.20
# 1       33074970  3.289230e+11     16.74            3.51  11.57    210.83
# 2       17130934  2.001330e+11     19.39            1.84   6.19    140.79
# 3       11080360  2.460380e+11     43.29            0.00  13.12    727.11
# 4       10319559  1.052470e+11     29.92            2.04   8.54    303.75

# %%
print(data_new.columns.tolist())
# Out:
# ['Date', 'Ticker', 'Open Price', 'Close Price', 'High Price', 'Low Price', 'Volume Traded', 'Market Cap', 'PE Ratio', 'Dividend Yield', 'EPS', '52 Week ']

# %%
## checking waht are the null values of dataset

# %%
data = data_new.isnull().sum()
data
# Out:
# Date              0
# Ticker            0
# Open Price        0
# Close Price       0
# High Price        0
# Low Price         0
# Volume Traded     0
# Market Cap        0
# PE Ratio          0
# Dividend Yield    0
# EPS               0
# 52 Week           0
# dtype: int64

# %%
## filter only AAPL compony related data from the dataset

# %%
data_AAPL = data_new[data_new['Ticker']=='AAPL'].copy()
data_AAPL
# Out:
#            Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0      6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 82     6/2/2025   AAPL      211.57       213.07      214.91     210.10
# 164    6/3/2025   AAPL      197.75       195.61      200.13     193.48
# 246    6/4/2025   AAPL      215.31       215.44      217.79     214.77
# 328    6/5/2025   AAPL      218.80       226.08      228.69     216.68
# 410    6/6/2025   AAPL      200.95       195.53      203.35     192.85
# 492    6/7/2025   AAPL      216.21       210.88      219.20     210.03
# 574    6/8/2025   AAPL      207.88       213.54      215.04     206.62
# 656    6/9/2025   AAPL      219.80       212.32      220.42     211.70
# 738   6/10/2025   AAPL      194.39       189.83      195.30     187.27
# 820   6/11/2025   AAPL      208.96       207.24      211.88     204.17
# 902   6/12/2025   AAPL      207.38       202.29      208.91     200.11
# ...

# %%
## reset the index numbers

# %%
data_AAPL.reset_index(drop=True, inplace=True)
data_AAPL
# Out:
#          Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0    6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1    6/2/2025   AAPL      211.57       213.07      214.91     210.10
# 2    6/3/2025   AAPL      197.75       195.61      200.13     193.48
# 3    6/4/2025   AAPL      215.31       215.44      217.79     214.77
# 4    6/5/2025   AAPL      218.80       226.08      228.69     216.68
# 5    6/6/2025   AAPL      200.95       195.53      203.35     192.85
# 6    6/7/2025   AAPL      216.21       210.88      219.20     210.03
# 7    6/8/2025   AAPL      207.88       213.54      215.04     206.62
# 8    6/9/2025   AAPL      219.80       212.32      220.42     211.70
# 9   6/10/2025   AAPL      194.39       189.83      195.30     187.27
# 10  6/11/2025   AAPL      208.96       207.24      211.88     204.17
# 11  6/12/2025   AAPL      207.38       202.29      208.91     200.11
# 12  6/13/2025   AAPL      216.46       223.10      225.00     214.46
# ...
