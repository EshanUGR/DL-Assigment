# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "E:/7th semester/Deep Learning/labs/DL-Assigment/data/stock_data.csv"
data = pd.read_csv(file_path)
data
# Out:
#            Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0      6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1      6/1/2025   ABBV      189.63       193.64      194.31     188.03
# 2      6/1/2025    ABT      118.79       120.08      120.53     118.01
# 3      6/1/2025   ADBE      584.51       567.78      587.97     561.25
# 4      6/1/2025    ADP      253.46       255.60      258.59     249.91
# ...         ...    ...         ...          ...         ...        ...
# 4341  7/23/2025   VRTX      478.20       489.78      491.84     476.65
# 4342  7/23/2025     VZ       46.61        47.75       48.26      46.15
# 4343  7/23/2025    WMT       71.65        70.99       72.35      70.46
# 4344  7/23/2025    XOM      117.02       112.37      118.45     111.41
# 4345  7/23/2025    ZTS      146.81       148.32      150.25     145.16
#
#       Volume Traded    Market Cap  PE Ratio  Dividend Yield    EPS  52 Week   \
# ...

# %%
data.groupby('Ticker')['Ticker'].agg('count')
# Out:
# Ticker
# AAPL    53
# ABBV    53
# ABT     53
# ADBE    53
# ADP     53
#         ..
# VRTX    53
# VZ      53
# WMT     53
# XOM     53
# ZTS     53
# Name: Ticker, Length: 82, dtype: int64

# %%
data_new = data.drop(['52_Week_Low', 'Sector'], axis='columns')
data_new.head()
# Out:
#        Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0  6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1  6/1/2025   ABBV      189.63       193.64      194.31     188.03
# 2  6/1/2025    ABT      118.79       120.08      120.53     118.01
# 3  6/1/2025   ADBE      584.51       567.78      587.97     561.25
# 4  6/1/2025    ADP      253.46       255.60      258.59     249.91
#
#    Volume Traded    Market Cap  PE Ratio  Dividend Yield    EPS  52 Week
# 0       42257183  2.931360e+12     28.37            0.49   6.62    248.20
# 1       33074970  3.289230e+11     16.74            3.51  11.57    210.83
# 2       17130934  2.001330e+11     19.39            1.84   6.19    140.79
# 3       11080360  2.460380e+11     43.29            0.00  13.12    727.11
# 4       10319559  1.052470e+11     29.92            2.04   8.54    303.75

# %%
plt.figure(figsize=(10,5))
plt.plot(data['Close Price'], label='Close Price')
plt.title("Stock Closing Price Over Time")
plt.xlabel("Compony")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
close_price = data['Close Price']  # use the exact column name
print(close_price[:5])
# Out:
# 0    187.79
# 1    193.64
# 2    120.08
# 3    567.78
# 4    255.60
# Name: Close Price, dtype: float64

# %%
## In a one day companies' close price ranges

# %%
import matplotlib.pyplot as plt

close_price = data['Close Price']


plt.figure(figsize=(12,6))
plt.plot(close_price[:83],label='close price')



plt.legend()
plt.xlabel("Compony")
plt.ylabel("Open Value/$")
plt.show()

# %%
## In second day companies' close price ranges

# %%
import matplotlib.pyplot as plt

close_price = data['Close Price']


plt.figure(figsize=(12,6))
plt.plot(close_price[84:167],label='close price')



plt.legend()
plt.xlabel("Compony")
plt.ylabel("Open Value/$")
plt.show()

# %%
## convert into a column vector in Open Price column's values

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

close_price = close_price.to_numpy().reshape(-1,1)


scaler = MinMaxScaler(feature_range=(0,1))
scalled_close_prices = scaler.fit_transform(close_price)

# %%
print(close_price[:50].T)
print(scalled_close_prices[:50].T)
# Out:
# [[ 187.79  193.64  120.08  567.78  255.6   168.78  302.81  206.84  162.71
#   1690.55   45.43 3676.42  873.77   53.74  436.58   65.95  384.87  234.62
#    863.35  280.4   156.17  115.1   104.17  561.86  175.57   79.6   173.56
#    469.09  369.95  219.24  184.32   31.38  653.96  451.65  166.89  211.91
#     70.26  970.7   484.23  248.55  480.99   72.19   94.36  522.61  219.32
#    133.74   97.4   441.16   80.07  679.2 ]]
# [[0.04355814 0.04506771 0.02608586 0.14161299 0.06105623 0.03865269
#   0.07323858 0.04847392 0.03708635 0.43133915 0.00682273 0.94378471
#   0.22057245 0.00896709 0.10775737 0.01211783 0.09441382 0.05564243
#   0.21788361 0.06745577 0.03539873 0.02480079 0.02198035 0.14008536
#   0.04040482 0.01564016 0.03988615 0.11614645 0.09056378 0.05167369
#   0.04266272 0.00319719 0.16385139 0.11164613 0.03816498 0.04978221
#   0.01323001 0.24558484 0.12005326 0.05923701 0.11921719 0.01372804
#   0.01944892 0.12995706 0.05169433 0.02961076 0.02023338 0.10893923
# ...

# %%
## I assume that predict values for the 'AAPL' company

# %%
data_AAPL = data[data['Ticker']=='AAPL'].copy()
data_AAPL
# Out:
#            Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0      6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 82     6/2/2025   AAPL      211.57       213.07      214.91     210.10
# 164    6/3/2025   AAPL      197.75       195.61      200.13     193.48
# 246    6/4/2025   AAPL      215.31       215.44      217.79     214.77
# 328    6/5/2025   AAPL      218.80       226.08      228.69     216.68
# 410    6/6/2025   AAPL      200.95       195.53      203.35     192.85
# 492    6/7/2025   AAPL      216.21       210.88      219.20     210.03
# 574    6/8/2025   AAPL      207.88       213.54      215.04     206.62
# 656    6/9/2025   AAPL      219.80       212.32      220.42     211.70
# 738   6/10/2025   AAPL      194.39       189.83      195.30     187.27
# 820   6/11/2025   AAPL      208.96       207.24      211.88     204.17
# 902   6/12/2025   AAPL      207.38       202.29      208.91     200.11
# ...

# %%
data_AAPL.reset_index(drop=True, inplace=True)

# %%
data_AAPL
# Out:
#          Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0    6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1    6/2/2025   AAPL      211.57       213.07      214.91     210.10
# 2    6/3/2025   AAPL      197.75       195.61      200.13     193.48
# 3    6/4/2025   AAPL      215.31       215.44      217.79     214.77
# 4    6/5/2025   AAPL      218.80       226.08      228.69     216.68
# 5    6/6/2025   AAPL      200.95       195.53      203.35     192.85
# 6    6/7/2025   AAPL      216.21       210.88      219.20     210.03
# 7    6/8/2025   AAPL      207.88       213.54      215.04     206.62
# 8    6/9/2025   AAPL      219.80       212.32      220.42     211.70
# 9   6/10/2025   AAPL      194.39       189.83      195.30     187.27
# 10  6/11/2025   AAPL      208.96       207.24      211.88     204.17
# 11  6/12/2025   AAPL      207.38       202.29      208.91     200.11
# 12  6/13/2025   AAPL      216.46       223.10      225.00     214.46
# ...

# %%
print(f"Filtered rows for AAPL: {len(data_AAPL)}")
print(data_AAPL.head())
# Out:
# Filtered rows for AAPL: 53
#        Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0  6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1  6/2/2025   AAPL      211.57       213.07      214.91     210.10
# 2  6/3/2025   AAPL      197.75       195.61      200.13     193.48
# 3  6/4/2025   AAPL      215.31       215.44      217.79     214.77
# 4  6/5/2025   AAPL      218.80       226.08      228.69     216.68
#
#    Volume Traded    Market Cap  PE Ratio  Dividend Yield   EPS  52 Week   \
# 0       42257183  2.931360e+12     28.37            0.49  6.62    248.20
# 1       49806398  3.325970e+12     25.98            0.51  8.20    258.68
# 2       29588431  3.053420e+12     30.35            0.52  6.45    233.17
# 3       38591730  3.362970e+12     25.26            0.47  8.53    288.47
# 4       73159323  3.529050e+12     30.97            0.46  7.30    284.50
#
#    52_Week_Low      Sector
# 0       155.68  Technology
# 1       176.02  Technology
# ...

# %%
## preprocessing the data after filtering the AAPL company data

# %%
data_new = data_AAPL.drop(['52_Week_Low','Sector'],axis='columns')
data_new
# Out:
#          Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0    6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1    6/2/2025   AAPL      211.57       213.07      214.91     210.10
# 2    6/3/2025   AAPL      197.75       195.61      200.13     193.48
# 3    6/4/2025   AAPL      215.31       215.44      217.79     214.77
# 4    6/5/2025   AAPL      218.80       226.08      228.69     216.68
# 5    6/6/2025   AAPL      200.95       195.53      203.35     192.85
# 6    6/7/2025   AAPL      216.21       210.88      219.20     210.03
# 7    6/8/2025   AAPL      207.88       213.54      215.04     206.62
# 8    6/9/2025   AAPL      219.80       212.32      220.42     211.70
# 9   6/10/2025   AAPL      194.39       189.83      195.30     187.27
# 10  6/11/2025   AAPL      208.96       207.24      211.88     204.17
# 11  6/12/2025   AAPL      207.38       202.29      208.91     200.11
# 12  6/13/2025   AAPL      216.46       223.10      225.00     214.46
# ...

# %%
print(data_new['Ticker'].unique())
# Out:
# ['AAPL']

# %%
data_new.shape
# Out:
# (53, 12)

# %%
import matplotlib.pyplot as plt

close_price = data_new['Close Price']


plt.figure(figsize=(12,6))

plt.plot(close_price,label='close price')



plt.legend()
plt.xlabel("Date")
plt.ylabel("Close Value/$")
plt.show()

# %%
## Visualize the open price, close price, high price, and law price belongs to the AAPL company

# %%
open_price = data_new['Open Price']
close_price = data_new['Close Price']
high_price = data_new['High Price']
low_price  = data_new['Low Price']




plt.figure(figsize=(12,6))
plt.plot(open_price, label='Open Price')
plt.plot(close_price, label='Close Price')
plt.plot(high_price, label='High Price')
plt.plot(low_price, label='Low Price')


plt.legend()
plt.xlabel("Date (Time)")
plt.ylabel("Price ($)")
plt.title("Stock Prices Over Time")
plt.show()

# %%
## specify the combination varience between close_price, volume_traded,market_cap, PE_ratio, dividend_yield, EPS

# %%
fig, ax1 = plt.subplots(figsize=(12,6))

ax1.plot(close_price, label='Close Price', color='blue')
ax1.plot(volume_traded, label='Volume Traded', color='orange')
ax1.set_ylabel('Price / Volume')

ax2 = ax1.twinx()  # second y-axis
ax2.plot(market_cap, label='Market Cap', color='green')
ax2.plot(pe_ratio, label='PE Ratio', color='red')
ax2.plot(dividend_yield, label='Dividend Yield', color='purple')
ax2.plot(eps, label='EPS', color='brown')
ax2.set_ylabel('Market Cap / Ratios')

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

plt.xlabel("Date (Time)")
plt.title("Stock Prices Over Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 4
#       1 fig, ax1 = plt.subplots(figsize=(12,6))
#       3 ax1.plot(close_price, label='Close Price', color='blue')
# ----> 4 ax1.plot(volume_traded, label='Volume Traded', color='orange')
#       5 ax1.set_ylabel('Price / Volume')
#       7 ax2 = ax1.twinx()  # second y-axis
#
# NameError: name 'volume_traded' is not defined

# %%
## after the above chart volume traded and market cap are partially depended and other features very poorly depend on the close price

# %%
## converting the scale values

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

close_price = close_price.to_numpy().reshape(-1,1)


scaler = MinMaxScaler(feature_range=(0,1))
scalled_close_prices = scaler.fit_transform(close_price)

# %%
print(close_price[:52].T)
print(scalled_close_prices[:52].T)
# Out:
# [[187.79 213.07 195.61 215.44 226.08 195.53 210.88 213.54 212.32 189.83
#   207.24 202.29 223.1  196.73 196.46 222.29 216.04 188.   195.78 194.79
#   198.86 203.9  197.39 222.   221.52 194.77 211.97 199.02 201.11 219.4
#   190.24 183.06 218.45 208.19 215.02 205.81 206.29 215.43 216.17 192.13
#   204.83 203.44 218.61 186.16 222.   221.57 207.31 201.64 228.2  229.93
#   196.05 200.44]]
# [[0.10091743 0.64028163 0.26776189 0.69084702 0.9178579  0.26605505
#   0.59355665 0.65030937 0.62427992 0.14444207 0.51589503 0.41028376
#   0.85427779 0.29165778 0.28589716 0.83699595 0.70364839 0.10539791
#   0.27138895 0.2502667  0.33710262 0.44463409 0.30573928 0.83080862
#   0.82056753 0.24983998 0.61681246 0.34051632 0.38510774 0.77533604
#   0.15318967 0.         0.75506721 0.53616386 0.68188607 0.48538511
#   0.4956262  0.69063367 0.70642202 0.19351397 0.46447621 0.43481971
#   0.7584809  0.06614039 0.83080862 0.82163431 0.51738852 0.39641562
#   0.9630894  1.         0.27714956 0.37081289]]

# %%
## creating features and labels and creating window size

# %%
data = []
target = []
window_size = 4

for i in range(0,window_size):
    data.append(scalled_close_prices[i:i+window_size])
    target.append(scalled_close_prices[i+window_size])

# %%
data_np=np.array(data)
target_np=np.array(target)

print(data_np.shape)
print(target_np.shape)
# Out:
# (4, 4, 1)
# (4, 1)

# %%
np.save('data',data)
np.save('target',target)

# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

# %%
train_data=data[:40]
train_target=target[:40]

test_data=data[40:]
test_target=target[40:]

print(train_data.shape)
print(test_data.shape)
print(train_target.shape)
print(test_target.shape)
# Out:
# (4, 4, 1)
# (0, 4, 1)
# (4, 1)
# (0, 1)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 data_AAPL.shape()
#
# TypeError: 'tuple' object is not callable
