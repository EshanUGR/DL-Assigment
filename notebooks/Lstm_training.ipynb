# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "E:/7th semester/Deep Learning/labs/DL-Assigment/data/stock_data.csv"
data = pd.read_csv(file_path)
data
# Out:
#            Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0      6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1      6/1/2025   ABBV      189.63       193.64      194.31     188.03
# 2      6/1/2025    ABT      118.79       120.08      120.53     118.01
# 3      6/1/2025   ADBE      584.51       567.78      587.97     561.25
# 4      6/1/2025    ADP      253.46       255.60      258.59     249.91
# ...         ...    ...         ...          ...         ...        ...
# 4341  7/23/2025   VRTX      478.20       489.78      491.84     476.65
# 4342  7/23/2025     VZ       46.61        47.75       48.26      46.15
# 4343  7/23/2025    WMT       71.65        70.99       72.35      70.46
# 4344  7/23/2025    XOM      117.02       112.37      118.45     111.41
# 4345  7/23/2025    ZTS      146.81       148.32      150.25     145.16
#
#       Volume Traded    Market Cap  PE Ratio  Dividend Yield    EPS  52 Week   \
# ...

# %%
data.groupby('Ticker')['Ticker'].agg('count')
# Out:
# Ticker
# AAPL    53
# ABBV    53
# ABT     53
# ADBE    53
# ADP     53
#         ..
# VRTX    53
# VZ      53
# WMT     53
# XOM     53
# ZTS     53
# Name: Ticker, Length: 82, dtype: int64

# %%
data_new = data.drop(['52_Week_Low', 'Sector'], axis='columns')
data_new.head()
# Out:
#        Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0  6/1/2025   AAPL      185.96       187.79      188.85     183.74
# 1  6/1/2025   ABBV      189.63       193.64      194.31     188.03
# 2  6/1/2025    ABT      118.79       120.08      120.53     118.01
# 3  6/1/2025   ADBE      584.51       567.78      587.97     561.25
# 4  6/1/2025    ADP      253.46       255.60      258.59     249.91
#
#    Volume Traded    Market Cap  PE Ratio  Dividend Yield    EPS  52 Week
# 0       42257183  2.931360e+12     28.37            0.49   6.62    248.20
# 1       33074970  3.289230e+11     16.74            3.51  11.57    210.83
# 2       17130934  2.001330e+11     19.39            1.84   6.19    140.79
# 3       11080360  2.460380e+11     43.29            0.00  13.12    727.11
# 4       10319559  1.052470e+11     29.92            2.04   8.54    303.75

# %%
plt.figure(figsize=(10,5))
plt.plot(data['Close Price'], label='Close Price')
plt.title("Stock Closing Price Over Time")
plt.xlabel("Days")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
open_price = data['Open Price']  # use the exact column name
print(open_price[:5])
# Out:
# 0    185.96
# 1    189.63
# 2    118.79
# 3    584.51
# 4    253.46
# Name: Open Price, dtype: float64

# %%
import matplotlib.pyplot as plt

open_price = data['Open Price']
# close_price = data[:,3]
# high_price = data[:,4]
# low_price = data[:5]

plt.figure(figsize=(12,6))
plt.plot(open_price[:100],label='open price')



plt.legend()
plt.xlabel("Date")
plt.ylabel("Open Value/$")
plt.show()

# %%
## cover into a column vector in Open Price column's values

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

open_price = open_price.reshape(-1,1)


scaler = MinMaxScaler(feature_range=(0,1))
scalled_open_prices = scaler.fit_transform(open_price)

# %%
print(open_price[:50].T)
print(scalled_open_prices[:50].T)
# Out:
# [[ 185.96  189.63  118.79  584.51  253.46  165.43  299.22  202.28  166.23
#   1698.77   45.   3742.26  874.99   52.76  431.9    65.08  384.02  237.87
#    876.35  271.59  158.18  114.27  105.44  571.5   171.5    79.59  175.92
#    457.99  377.18  217.25  186.67   32.42  672.27  450.23  164.64  207.75
#     69.69  964.42  487.43  253.18  469.91   71.04   93.41  517.09  213.99
#    134.91   99.67  431.7    81.08  677.17]]
# [[0.04359215 0.04455059 0.0260503  0.14767584 0.06122017 0.03823062
#   0.07317067 0.04785421 0.03843954 0.43867145 0.00677961 0.97234098
#   0.22353642 0.00880618 0.10782084 0.01202362 0.09531669 0.05714875
#   0.22389159 0.06595493 0.03633724 0.02486988 0.02256387 0.1442782
#   0.03981583 0.01581299 0.04097014 0.11463439 0.09353038 0.05176372
#   0.04377757 0.00349427 0.17059489 0.11260782 0.0380243  0.04928274
#   0.01322755 0.24689159 0.12232283 0.06114705 0.11774737 0.01358011
#   0.01942217 0.13006871 0.05091235 0.03026014 0.021057   0.10776861
# ...
